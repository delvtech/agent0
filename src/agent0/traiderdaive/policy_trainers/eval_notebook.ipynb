# %%
import os

import gymnasium as gym
from stable_baselines3 import A2C
from stable_baselines3.common.monitor import Monitor
from agent0.traiderdaive import FullHyperdriveEnv

# %%
# Parameters
"""Runs an evaluation episode from a saved model."""
# Create log dirs
log_dir = "../../../../.saved_models/full_model_saved_3_8_2024/"

# %%
gym_config = FullHyperdriveEnv.Config(eval_mode=True)
env = gym.make("traiderdaive/full_hyperdrive_env", gym_config=gym_config)
env = Monitor(env, log_dir)

model = A2C.load(log_dir + "/best_model.zip", device="cpu")

# %%
# Run dashboard from env
env.interactive_hyperdrive.run_dashboard()

# %%
# Run Evaluation
obs, _ = env.reset()
while True:
    action, _states = model.predict(obs, deterministic=True)
    obs, _, terminated, truncated, _ = env.step(action)
    if terminated or truncated:
        break
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 5
#       3 while True:
#       4     action, _states = model.predict(obs, deterministic=True)
# ----> 5     obs, _, terminated, truncated, _ = env.step(action)
#       6     if terminated or truncated:
#       7         break
#
# File ~/workspace/agent0/.venv/lib/python3.10/site-packages/stable_baselines3/common/monitor.py:94, in Monitor.step(self, action)
#      92 if self.needs_reset:
#      93     raise RuntimeError("Tried to step environment that needs reset")
# ---> 94 observation, reward, terminated, truncated, info = self.env.step(action)
#      95 self.rewards.append(float(reward))
#      96 if terminated or truncated:
#
# File ~/workspace/agent0/.venv/lib/python3.10/site-packages/gymnasium/wrappers/time_limit.py:57, in TimeLimit.step(self, action)
#      46 def step(self, action):
#      47     """Steps through the environment and if the number of steps elapsed exceeds ``max_episode_steps`` then truncate.
#      48
#      49     Args:
#    (...)
#      55
#      56     """
# ---> 57     observation, reward, terminated, truncated, info = self.env.step(action)
#      58     self._elapsed_steps += 1
#      60     if self._elapsed_steps >= self._max_episode_steps:
#
# File ~/workspace/agent0/.venv/lib/python3.10/site-packages/gymnasium/wrappers/order_enforcing.py:56, in OrderEnforcing.step(self, action)
#      54 if not self._has_reset:
#      55     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# ---> 56 return self.env.step(action)
#
# File ~/workspace/agent0/.venv/lib/python3.10/site-packages/gymnasium/wrappers/env_checker.py:51, in PassiveEnvChecker.step(self, action)
#      49     return env_step_passive_checker(self.env, action)
#      50 else:
# ---> 51     return self.env.step(action)
#
# File ~/workspace/agent0/src/agent0/traiderdaive/gym_environments/full_hyperdrive_env.py:413, in FullHyperdriveEnv.step(self, action)
#     385 def step(self, action: np.ndarray) -> tuple[dict[str, np.ndarray], float, bool, bool, dict[str, Any]]:
#     386     """Takes a step in the the environment.
#     387
#     388     Arguments
#    (...)
#     410             Contains auxiliary diagnostic information for debugging, learning, logging.
#     411     """
# --> 413     truncated = self._apply_action(action)
#     415     # Run other bots
#     416     for random_bot in self.random_bots:
#
# File ~/workspace/agent0/src/agent0/traiderdaive/gym_environments/full_hyperdrive_env.py:370, in FullHyperdriveEnv._apply_action(self, action)
#     368 try:
#     369     if add_lp:
# --> 370         self.rl_bot.add_liquidity(add_lp_volume)
#     371     if remove_lp and remove_lp_volume <= self.rl_bot.wallet.lp_tokens:
#     372         self.rl_bot.remove_liquidity(remove_lp_volume)
#
# File ~/workspace/agent0/src/agent0/core/hyperdrive/interactive/i_hyperdrive_agent.py:158, in IHyperdriveAgent.add_liquidity(self, base)
#     145 def add_liquidity(self, base: FixedPoint) -> AddLiquidity:
#     146     """Adds liquidity for this agent.
#     147
#     148     Arguments
#    (...)
#     156         The emitted event of the add liquidity call.
#     157     """
# --> 158     return self._pool._add_liquidity(self.agent, base)
#
# File ~/workspace/agent0/src/agent0/core/hyperdrive/interactive/i_local_hyperdrive.py:1148, in ILocalHyperdrive._add_liquidity(self, agent, base)
#    1145 # Experimental changes runs data pipeline in thread
#    1146 # Turn that off here to run in slow, but won't crash mode
#    1147 if not self.chain.experimental_data_threading:
# -> 1148     self._run_blocking_data_pipeline()
#    1149 return out
#
# File ~/workspace/agent0/src/agent0/core/hyperdrive/interactive/i_local_hyperdrive.py:404, in ILocalHyperdrive._run_blocking_data_pipeline(self, start_block)
#     401 if start_block is None:
#     402     start_block = self._deploy_block_number
# --> 404 acquire_data(
#     405     start_block=start_block,  # Start block is the block hyperdrive was deployed
#     406     interface=self.interface,
#     407     db_session=self.db_session,
#     408     exit_on_catch_up=True,
#     409     suppress_logs=True,
#     410 )
#     411 data_analysis(
#     412     start_block=start_block,
#     413     interface=self.interface,
#    (...)
#     417     calc_pnl=self.calc_pnl,
#     418 )
#
# File ~/workspace/agent0/src/agent0/chainsync/exec/acquire_data.py:134, in acquire_data(start_block, lookback_block_limit, interface, eth_config, db_session, postgres_config, contract_addresses, exit_on_catch_up, exit_callback_fn, suppress_logs)
#     128             logging.warning(
#     129                 "Querying block_number %s out of %s, unable to keep up with chain block iteration",
#     130                 block_number,
#     131                 latest_mined_block,
#     132             )
#     133             continue
# --> 134         data_chain_to_db(interface, interface.get_block(block_number), db_session)
#     135     curr_write_block = latest_mined_block + 1
#     137 # Clean up resources on clean exit
#     138 # If this function made the db session, we close it here
#
# File ~/workspace/agent0/src/agent0/chainsync/db/hyperdrive/chain_to_db.py:72, in data_chain_to_db(interface, block, session)
#      69 # When the contract call fails due to missing checkpoint, solidity returns 0
#      70 # Hence, we detect that here and don't add the checkpoint info if that happens
#      71 if block_checkpoint_info.vault_share_price != 0:
# ---> 72     add_checkpoint_info(block_checkpoint_info, session)
#      74 ## Query and add block_transactions and wallet deltas
#      75 block_transactions = None
#
# File ~/workspace/agent0/src/agent0/chainsync/db/hyperdrive/interface.py:149, in add_checkpoint_info(checkpoint_info, session)
#     147 session.add(checkpoint_info)
#     148 try:
# --> 149     session.commit()
#     150 except exc.DataError as err:
#     151     session.rollback()
#
# File ~/workspace/agent0/.venv/lib/python3.10/site-packages/sqlalchemy/orm/session.py:1972, in Session.commit(self)
#    1969 if trans is None:
#    1970     trans = self._autobegin_t()
# -> 1972 trans.commit(_to_root=True)
#
# File <string>:2, in commit(self, _to_root)
#
# File ~/workspace/agent0/.venv/lib/python3.10/site-packages/sqlalchemy/orm/state_changes.py:139, in _StateChange.declare_states.<locals>._go(fn, self, *arg, **kw)
#     137 self._next_state = _StateChangeStates.CHANGE_IN_PROGRESS
#     138 try:
# --> 139     ret_value = fn(self, *arg, **kw)
#     140 except:
#     141     raise
#
# File ~/workspace/agent0/.venv/lib/python3.10/site-packages/sqlalchemy/orm/session.py:1264, in SessionTransaction.commit(self, _to_root)
#    1260 for conn, trans, should_commit, autoclose in set(
#    1261     self._connections.values()
#    1262 ):
#    1263     if should_commit:
# -> 1264         trans.commit()
#    1266 self._state = SessionTransactionState.COMMITTED
#    1267 self.session.dispatch.after_commit(self.session)
#
# File ~/workspace/agent0/.venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py:2632, in Transaction.commit(self)
#    2616 """Commit this :class:`.Transaction`.
#    2617
#    2618 The implementation of this may vary based on the type of transaction in
#    (...)
#    2629
#    2630 """
#    2631 try:
# -> 2632     self._do_commit()
#    2633 finally:
#    2634     assert not self.is_active
#
# File ~/workspace/agent0/.venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py:2737, in RootTransaction._do_commit(self)
#    2734 assert self.connection._transaction is self
#    2736 try:
# -> 2737     self._connection_commit_impl()
#    2738 finally:
#    2739     # whether or not commit succeeds, cancel any
#    2740     # nested transactions, make this transaction "inactive"
#    2741     # and remove it as a reset agent
#    2742     if self.connection._nested_transaction:
#
# File ~/workspace/agent0/.venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py:2708, in RootTransaction._connection_commit_impl(self)
#    2707 def _connection_commit_impl(self) -> None:
# -> 2708     self.connection._commit_impl()
#
# File ~/workspace/agent0/.venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1149, in Connection._commit_impl(self)
#    1147     self.engine.dialect.do_commit(self.connection)
#    1148 except BaseException as e:
# -> 1149     self._handle_dbapi_exception(e, None, None, None, None)
#
# File ~/workspace/agent0/.venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py:2359, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2357     else:
#    2358         assert exc_info[1] is not None
# -> 2359         raise exc_info[1].with_traceback(exc_info[2])
#    2360 finally:
#    2361     del self._reentrant_error
#
# File ~/workspace/agent0/.venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1147, in Connection._commit_impl(self)
#    1145         self._log_info("COMMIT")
#    1146 try:
# -> 1147     self.engine.dialect.do_commit(self.connection)
#    1148 except BaseException as e:
#    1149     self._handle_dbapi_exception(e, None, None, None, None)
#
# File ~/workspace/agent0/.venv/lib/python3.10/site-packages/sqlalchemy/engine/default.py:695, in DefaultDialect.do_commit(self, dbapi_connection)
#     694 def do_commit(self, dbapi_connection):
# --> 695     dbapi_connection.commit()
#
# File ~/workspace/agent0/.venv/lib/python3.10/site-packages/psycopg/connection.py:896, in Connection.commit(self)
#     894 """Commit any pending transaction to the database."""
#     895 with self.lock:
# --> 896     self.wait(self._commit_gen())
#
# File ~/workspace/agent0/.venv/lib/python3.10/site-packages/psycopg/connection.py:969, in Connection.wait(self, gen, timeout)
#     962 """
#     963 Consume a generator operating on the connection.
#     964
#     965 The function must be used on generators that don't change connection
#     966 fd (i.e. not on connect and reset).
#     967 """
#     968 try:
# --> 969     return waiting.wait(gen, self.pgconn.socket, timeout=timeout)
#     970 except KeyboardInterrupt:
#     971     # On Ctrl-C, try to cancel the query in the server, otherwise
#     972     # the connection will remain stuck in ACTIVE state.
#     973     self._try_cancel(self.pgconn)
#
# File psycopg_binary/_psycopg/waiting.pyx:193, in psycopg_binary._psycopg.wait_c()
#
# KeyboardInterrupt:

# %%
env.chain.cleanup()
