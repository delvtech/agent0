# %%
import os

import gymnasium as gym
from stable_baselines3 import A2C
from stable_baselines3.common.monitor import Monitor
from traiderdaive import FullHyperdriveEnv

# %%
# Parameters
"""Runs an evaluation episode from a saved model."""
# Create log dirs
log_dir = "../../../../.saved_models/full_model_saved_3_5_2024/"

# %%
gym_config = FullHyperdriveEnv.Config(eval_mode=True)
env = gym.make("traiderdaive/full_hyperdrive_env", gym_config=gym_config)
env = Monitor(env, log_dir)

model = A2C.load(log_dir + "/best_model.zip", device="cpu")

# %%
# Run dashboard from env
env.interactive_hyperdrive.run_dashboard()

# %%
# Run Evaluation
obs, _ = env.reset()
while True:
    action, _states = model.predict(obs, deterministic=True)
    obs, _, terminated, truncated, _ = env.step(action)
    if terminated or truncated:
        break
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/workspace/agent0/.venv/lib/python3.10/site-packages/cytoolz/functoolz.pyx:263, in cytoolz.functoolz.curry.__call__()
#
# TypeError: abi_data_tree() missing 1 required positional argument: 'data'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 5
#       3 while True:
#       4     action, _states = model.predict(obs, deterministic=True)
# ----> 5     obs, _, terminated, truncated, _ = env.step(action)
#       6     if terminated or truncated:
#       7         break
#
# File ~/workspace/agent0/.venv/lib/python3.10/site-packages/stable_baselines3/common/monitor.py:94, in Monitor.step(self, action)
#      92 if self.needs_reset:
#      93     raise RuntimeError("Tried to step environment that needs reset")
# ---> 94 observation, reward, terminated, truncated, info = self.env.step(action)
#      95 self.rewards.append(float(reward))
#      96 if terminated or truncated:
#
# File ~/workspace/agent0/.venv/lib/python3.10/site-packages/gymnasium/wrappers/time_limit.py:57, in TimeLimit.step(self, action)
#      46 def step(self, action):
#      47     """Steps through the environment and if the number of steps elapsed exceeds ``max_episode_steps`` then truncate.
#      48
#      49     Args:
#    (...)
#      55
#      56     """
# ---> 57     observation, reward, terminated, truncated, info = self.env.step(action)
#      58     self._elapsed_steps += 1
#      60     if self._elapsed_steps >= self._max_episode_steps:
#
# File ~/workspace/agent0/.venv/lib/python3.10/site-packages/gymnasium/wrappers/order_enforcing.py:56, in OrderEnforcing.step(self, action)
#      54 if not self._has_reset:
#      55     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# ---> 56 return self.env.step(action)
#
# File ~/workspace/agent0/.venv/lib/python3.10/site-packages/gymnasium/wrappers/env_checker.py:51, in PassiveEnvChecker.step(self, action)
#      49     return env_step_passive_checker(self.env, action)
#      50 else:
# ---> 51     return self.env.step(action)
#
# File ~/workspace/agent0/lib/traiderdaive/traiderdaive/gym_environments/full_hyperdrive_env.py:397, in FullHyperdriveEnv.step(self, action)
#     395 for random_bot in self.random_bots:
#     396     try:
# --> 397         random_bot.execute_policy_action()
#     398     except Exception as err:  # pylint: disable=broad-except
#     399         print(f"Warning: Failed to execute random bot: {err=}")
#
# File ~/workspace/agent0/lib/agent0/agent0/hyperdrive/interactive/i_hyperdrive_agent.py:200, in IHyperdriveAgent.execute_policy_action(self)
#     190 def execute_policy_action(
#     191     self,
#     192 ) -> list[OpenLong | OpenShort | CloseLong | CloseShort | AddLiquidity | RemoveLiquidity | RedeemWithdrawalShares]:
#     193     """Executes the underlying policy action (if set).
#     194
#     195     Returns
#    (...)
#     198         Events of the executed actions.
#     199     """
# --> 200     return self._pool._execute_policy_action(self.agent)
#
# File ~/workspace/agent0/lib/agent0/agent0/hyperdrive/interactive/i_local_hyperdrive.py:1110, in ILocalHyperdrive._execute_policy_action(self, agent)
#    1107 def _execute_policy_action(
#    1108     self, agent: HyperdriveAgent
#    1109 ) -> list[OpenLong | OpenShort | CloseLong | CloseShort | AddLiquidity | RemoveLiquidity | RedeemWithdrawalShares]:
# -> 1110     out = super()._execute_policy_action(agent)
#    1111     # Experimental changes runs data pipeline in thread
#    1112     # Turn that off here to run in slow, but won't crash mode
#    1113     if not self.chain.experimental_data_threading:
#
# File ~/workspace/agent0/lib/agent0/agent0/hyperdrive/interactive/i_hyperdrive.py:340, in IHyperdrive._execute_policy_action(self, agent)
#     337     raise ValueError("Must pass in a policy in the constructor to execute policy action.")
#     339 agent.policy.set_next_action_from_sub_policy()
# --> 340 trade_results: list[TradeResult] = asyncio.run(
#     341     async_execute_agent_trades(self.interface, [agent], liquidate=False, interactive_mode=True)
#     342 )
#     343 out_events = []
#     344 # The underlying policy can execute multiple actions in one step
#
# File ~/workspace/agent0/.venv/lib/python3.10/site-packages/nest_asyncio.py:30, in _patch_asyncio.<locals>.run(main, debug)
#      28 task = asyncio.ensure_future(main)
#      29 try:
# ---> 30     return loop.run_until_complete(task)
#      31 finally:
#      32     if not task.done():
#
# File ~/workspace/agent0/.venv/lib/python3.10/site-packages/nest_asyncio.py:92, in _patch_loop.<locals>.run_until_complete(self, future)
#      90     f._log_destroy_pending = False
#      91 while not f.done():
# ---> 92     self._run_once()
#      93     if self._stopping:
#      94         break
#
# File ~/workspace/agent0/.venv/lib/python3.10/site-packages/nest_asyncio.py:133, in _patch_loop.<locals>._run_once(self)
#     130 curr_task = curr_tasks.pop(self, None)
#     132 try:
# --> 133     handle._run()
#     134 finally:
#     135     # restore the current task
#     136     if curr_task is not None:
#
# File ~/.pyenv/versions/3.10.11/lib/python3.10/asyncio/events.py:80, in Handle._run(self)
#      78 def _run(self):
#      79     try:
# ---> 80         self._context.run(self._callback, *self._args)
#      81     except (SystemExit, KeyboardInterrupt):
#      82         raise
#
# File ~/.pyenv/versions/3.10.11/lib/python3.10/asyncio/tasks.py:232, in Task.__step(***failed resolving arguments***)
#     228 try:
#     229     if exc is None:
#     230         # We use the `send` method directly, because coroutines
#     231         # don't have `__iter__` and `__next__` methods.
# --> 232         result = coro.send(None)
#     233     else:
#     234         result = coro.throw(exc)
#
# File ~/workspace/agent0/lib/agent0/agent0/hyperdrive/exec/execute_agent_trades.py:72, in async_execute_single_agent_trade(agent, interface, liquidate, randomize_liquidation, interactive_mode)
#      68     trades: list[Trade[HyperdriveMarketAction]] = agent.get_liquidation_trades(
#      69         interface, randomize_liquidation, interactive_mode
#      70     )
#      71 else:
# ---> 72     trades: list[Trade[HyperdriveMarketAction]] = agent.get_trades(interface=interface.get_read_interface())
#      74 # Make trades async for this agent. This way, an agent can submit multiple trades for a single block
#      75 # To do this, we need to manually set the nonce, so we get the base transaction count here
#      76 # and pass in an incrementing nonce per call
#      77 # TODO figure out which exception here to retry on
#      78 base_nonce = retry_call(
#      79     DEFAULT_READ_RETRY_COUNT, None, interface.web3.eth.get_transaction_count, agent.checksum_address
#      80 )
#
# File ~/workspace/agent0/lib/ethpy/ethpy/hyperdrive/interface/read_write_interface.py:79, in HyperdriveReadWriteInterface.get_read_interface(self)
#      71 def get_read_interface(self) -> HyperdriveReadInterface:
#      72     """Return the current instance as an instance of the parent (HyperdriveReadInterface) class.
#      73
#      74     Returns
#    (...)
#      77         This instantiated object, but as a ReadInterface.
#      78     """
# ---> 79     return HyperdriveReadInterface(self.eth_config, self.addresses, self.web3, self.read_retry_count)
#
# File ~/workspace/agent0/lib/ethpy/ethpy/hyperdrive/interface/read_interface.py:129, in HyperdriveReadInterface.__init__(self, eth_config, addresses, web3, read_retry_count)
#     125 self.hyperdrive_factory_contract: HyperdriveFactoryContract = HyperdriveFactoryContract.factory(w3=self.web3)(
#     126     web3.to_checksum_address(self.addresses.factory)
#     127 )
#     128 # Fill in the initial state cache.
# --> 129 self._current_pool_state = self.get_hyperdrive_state()
#     130 self.last_state_block_number = copy.copy(self._current_pool_state.block_number)
#     131 self.pool_config = self._current_pool_state.pool_config
#
# File ~/workspace/agent0/lib/ethpy/ethpy/hyperdrive/interface/read_interface.py:263, in HyperdriveReadInterface.get_hyperdrive_state(self, block)
#     261 pool_info = get_hyperdrive_pool_info(self.hyperdrive_contract, block_number)
#     262 checkpoint_time = self.calc_checkpoint_id(pool_config.checkpoint_duration, self.get_block_timestamp(block))
# --> 263 checkpoint = get_hyperdrive_checkpoint(self.hyperdrive_contract, checkpoint_time)
#     264 exposure = get_hyperdrive_checkpoint_exposure(self.hyperdrive_contract, checkpoint_time)
#     265 variable_rate = self.get_variable_rate(block_number)
#
# File ~/workspace/agent0/lib/ethpy/ethpy/hyperdrive/transactions.py:77, in get_hyperdrive_checkpoint(hyperdrive_contract, checkpoint_time)
#      60 def get_hyperdrive_checkpoint(
#      61     hyperdrive_contract: IERC4626HyperdriveContract, checkpoint_time: Timestamp
#      62 ) -> CheckpointFP:
#      63     """Get the checkpoint info for the Hyperdrive contract at a given block.
#      64
#      65     Arguments
#    (...)
#      75         The dataclass containing the checkpoint info in fixed point
#      76     """
# ---> 77     checkpoint = hyperdrive_contract.functions.getCheckpoint(checkpoint_time).call()
#      78     return checkpoint_to_fixedpoint(checkpoint)
#
# File ~/workspace/agent0/lib/hypertypes/hypertypes/types/IERC4626HyperdriveContract.py:392, in IERC4626HyperdriveGetCheckpointContractFunction.call(self, transaction, block_identifier, state_override, ccip_read_enabled)
#     388 return_types = Checkpoint
#     390 # Call the function
# --> 392 raw_values = super().call(transaction, block_identifier, state_override, ccip_read_enabled)
#     393 return cast(Checkpoint, rename_returned_types(structs, return_types, raw_values))
#
# File ~/workspace/agent0/.venv/lib/python3.10/site-packages/web3/contract/contract.py:305, in ContractFunction.call(self, transaction, block_identifier, state_override, ccip_read_enabled)
#     301 call_transaction = self._get_call_txparams(transaction)
#     303 block_id = parse_block_identifier(self.w3, block_identifier)
# --> 305 return call_contract_function(
#     306     self.w3,
#     307     self.address,
#     308     self._return_data_normalizers,
#     309     self.function_identifier,
#     310     call_transaction,
#     311     block_id,
#     312     self.contract_abi,
#     313     self.abi,
#     314     state_override,
#     315     ccip_read_enabled,
#     316     self.decode_tuples,
#     317     *self.args,
#     318     **self.kwargs,
#     319 )
#
# File ~/workspace/agent0/.venv/lib/python3.10/site-packages/web3/contract/utils.py:96, in call_contract_function(w3, address, normalizers, function_identifier, transaction, block_id, contract_abi, fn_abi, state_override, ccip_read_enabled, decode_tuples, *args, **kwargs)
#      81 """
#      82 Helper function for interacting with a contract function using the
#      83 `eth_call` API.
#      84 """
#      85 call_transaction = prepare_transaction(
#      86     address,
#      87     w3,
#    (...)
#      93     fn_kwargs=kwargs,
#      94 )
# ---> 96 return_data = w3.eth.call(
#      97     call_transaction,
#      98     block_identifier=block_id,
#      99     state_override=state_override,
#     100     ccip_read_enabled=ccip_read_enabled,
#     101 )
#     103 if fn_abi is None:
#     104     fn_abi = find_matching_fn_abi(
#     105         contract_abi, w3.codec, function_identifier, args, kwargs
#     106     )
#
# File ~/workspace/agent0/.venv/lib/python3.10/site-packages/web3/eth/eth.py:259, in Eth.call(self, transaction, block_identifier, state_override, ccip_read_enabled)
#     249 ccip_read_enabled_on_provider = self.w3.provider.global_ccip_read_enabled
#     250 if (
#     251     # default conditions:
#     252     ccip_read_enabled_on_provider
#    (...)
#     257     and ccip_read_enabled is True
#     258 ):
# --> 259     return self._durin_call(transaction, block_identifier, state_override)
#     261 return self._call(transaction, block_identifier, state_override)
#
# File ~/workspace/agent0/.venv/lib/python3.10/site-packages/web3/eth/eth.py:278, in Eth._durin_call(self, transaction, block_identifier, state_override)
#     276 for _ in range(max_redirects):
#     277     try:
# --> 278         return self._call(transaction, block_identifier, state_override)
#     279     except OffchainLookup as offchain_lookup:
#     280         durin_calldata = handle_offchain_lookup(
#     281             offchain_lookup.payload, transaction
#     282         )
#
# File ~/workspace/agent0/.venv/lib/python3.10/site-packages/web3/module.py:64, in retrieve_blocking_method_call_fn.<locals>.caller(*args, **kwargs)
#      62 def caller(*args: Any, **kwargs: Any) -> Union[TReturn, LogFilter]:
#      63     try:
# ---> 64         (method_str, params), response_formatters = method.process_params(
#      65             module, *args, **kwargs
#      66         )
#      67     except _UseExistingFilter as err:
#      68         return LogFilter(eth_module=module, filter_id=err.filter_id)
#
# File ~/workspace/agent0/.venv/lib/python3.10/site-packages/web3/method.py:210, in Method.process_params(self, module, *args, **kwargs)
#     202 method = self.method_selector_fn()
#     203 response_formatters = (
#     204     self.result_formatters(method, module),
#     205     get_error_formatters(method),
#     206     self.null_result_formatters(method),
#     207 )
#     208 request = (
#     209     method,
# --> 210     _apply_request_formatters(params, self.request_formatters(method)),
#     211 )
#     212 return request, response_formatters
#
# File ~/workspace/agent0/.venv/lib/python3.10/site-packages/eth_utils/functional.py:47, in apply_to_return_value.<locals>.outer.<locals>.inner(*args, **kwargs)
#      45 @functools.wraps(fn)
#      46 def inner(*args, **kwargs) -> T:  # type: ignore
# ---> 47     return callback(fn(*args, **kwargs))
#
# File ~/workspace/agent0/.venv/lib/python3.10/site-packages/web3/method.py:55, in _apply_request_formatters(params, request_formatters)
#      50 @to_tuple
#      51 def _apply_request_formatters(
#      52     params: Any, request_formatters: Dict[RPCEndpoint, Callable[..., TReturn]]
#      53 ) -> Tuple[Any, ...]:
#      54     if request_formatters:
# ---> 55         formatted_params = pipe(params, request_formatters)
#      56         return formatted_params
#      57     return params
#
# File ~/workspace/agent0/.venv/lib/python3.10/site-packages/cytoolz/functoolz.pyx:680, in cytoolz.functoolz.pipe()
#
# File ~/workspace/agent0/.venv/lib/python3.10/site-packages/cytoolz/functoolz.pyx:655, in cytoolz.functoolz.c_pipe()
#
# File ~/workspace/agent0/.venv/lib/python3.10/site-packages/cytoolz/functoolz.pyx:518, in cytoolz.functoolz.Compose.__call__()
#
# File ~/workspace/agent0/.venv/lib/python3.10/site-packages/cytoolz/functoolz.pyx:263, in cytoolz.functoolz.curry.__call__()
#
# File ~/workspace/agent0/.venv/lib/python3.10/site-packages/eth_utils/decorators.py:102, in return_arg_type.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     100 result = to_wrap(*args, **kwargs)
#     101 ReturnType = type(args[at_position])
# --> 102 return ReturnType(result)
#
# File ~/workspace/agent0/.venv/lib/python3.10/site-packages/eth_utils/applicators.py:36, in apply_formatter_at_index(formatter, at_index, value)
#      34 for index, item in enumerate(value):
#      35     if index == at_index:
# ---> 36         yield formatter(item)
#      37     else:
#      38         yield item
#
# File ~/workspace/agent0/.venv/lib/python3.10/site-packages/cytoolz/functoolz.pyx:263, in cytoolz.functoolz.curry.__call__()
#
# File ~/workspace/agent0/.venv/lib/python3.10/site-packages/web3/_utils/rpc_abi.py:237, in apply_abi_formatters_to_dict(normalizers, abi_dict, data)
#     230 @curry
#     231 def apply_abi_formatters_to_dict(
#     232     normalizers: Sequence[Callable[[TypeStr, Any], Tuple[TypeStr, Any]]],
#     233     abi_dict: Dict[str, Any],
#     234     data: Dict[Any, Any],
#     235 ) -> Dict[Any, Any]:
#     236     fields = list(abi_dict.keys() & data.keys())
# --> 237     formatted_values = map_abi_data(
#     238         normalizers,
#     239         [abi_dict[field] for field in fields],
#     240         [data[field] for field in fields],
#     241     )
#     242     formatted_dict = dict(zip(fields, formatted_values))
#     243     return dict(data, **formatted_dict)
#
# File ~/workspace/agent0/.venv/lib/python3.10/site-packages/cytoolz/functoolz.pyx:263, in cytoolz.functoolz.curry.__call__()
#
# File ~/workspace/agent0/.venv/lib/python3.10/site-packages/web3/_utils/abi.py:736, in map_abi_data(normalizers, types, data)
#     707 @curry
#     708 def map_abi_data(
#     709     normalizers: Sequence[Callable[[TypeStr, Any], Tuple[TypeStr, Any]]],
#     710     types: Sequence[TypeStr],
#     711     data: Sequence[Any],
#     712 ) -> Any:
#     713     """
#     714     This function will apply normalizers to your data, in the
#     715     context of the relevant types. Each normalizer is in the format:
#    (...)
#     733     3. Stripping the types back out of the tree
#     734     """
#     735     pipeline = itertools.chain(
# --> 736         [abi_data_tree(types)],
#     737         map(data_tree_map, normalizers),
#     738         [partial(recursive_map, strip_abi_type)],
#     739     )
#     741     return pipe(data, *pipeline)
#
# File ~/workspace/agent0/.venv/lib/python3.10/site-packages/cytoolz/functoolz.pyx:265, in cytoolz.functoolz.curry.__call__()
#
# File ~/workspace/agent0/.venv/lib/python3.10/site-packages/cytoolz/functoolz.pyx:292, in cytoolz.functoolz.curry._should_curry_internal()
#
# File ~/workspace/agent0/.venv/lib/python3.10/site-packages/toolz/functoolz.py:911, in is_partial_args(func, args, kwargs, sigspec)
#     909     return rv
#     910 try:
# --> 911     sigspec.bind_partial(*args, **kwargs)
#     912 except TypeError:
#     913     return False
#
# File ~/.pyenv/versions/3.10.11/lib/python3.10/inspect.py:3193, in Signature.bind_partial(self, *args, **kwargs)
#    3188 def bind_partial(self, /, *args, **kwargs):
#    3189     """Get a BoundArguments object, that partially maps the
#    3190     passed `args` and `kwargs` to the function's signature.
#    3191     Raises `TypeError` if the passed arguments can not be bound.
#    3192     """
# -> 3193     return self._bind(args, kwargs, partial=True)
#
# File ~/.pyenv/versions/3.10.11/lib/python3.10/inspect.py:3140, in Signature._bind(self, args, kwargs, partial)
#    3137     kwargs_param = param
#    3138     continue
# -> 3140 if param.kind == _VAR_POSITIONAL:
#    3141     # Named arguments don't refer to '*args'-like parameters.
#    3142     # We only arrive here if the positional arguments ended
#    3143     # before reaching the last parameter before *args.
#    3144     continue
#    3146 param_name = param.name
#
# File ~/.pyenv/versions/3.10.11/lib/python3.10/inspect.py:2699, in Parameter.kind(self)
#    2695 @property
#    2696 def annotation(self):
#    2697     return self._annotation
# -> 2699 @property
#    2700 def kind(self):
#    2701     return self._kind
#    2703 def replace(self, *, name=_void, kind=_void,
#    2704             annotation=_void, default=_void):
#
# KeyboardInterrupt:

# %%
env.chain.cleanup()
